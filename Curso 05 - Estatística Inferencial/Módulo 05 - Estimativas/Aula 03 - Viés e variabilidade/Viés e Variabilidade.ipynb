# %% [markdown]
# # 🌈 Objetivos da Aula:

# %% [markdown]
# * Compreender o que é viés em um estimador
# * Entender o conceito de variabilidade (ou variabilidade amostral)
# * Diferenciar estimadores viesados de não viesados
# * Compreender o impacto do tamanho da amostra e do número de amostras

# %% [markdown]
# #🔍 Introdução

# %% [markdown]
# Em estatística, muitas vezes estamos tentando estimar um parâmetro populacional (como a média, variância, proporção, etc) com base em amostras da população. Mas o quão bom é o nosso estimador?
#
# Existem duas características fundamentais para avaliar um estimador:
#
# * Viés (bias): Um estimador é viesado quando seu valor esperado não é igual ao parâmetro que ele tenta estimar.
#
# * Variabilidade (variability): A variabilidade representa o quanto o estimador varia de amostra para amostra. Mesmo estimadores não viesados podem ter grande variabilidade, o que afeta a precisão das estimativas.

# %% [markdown]
# #🎓 Exemplos

# %%
from numpy import linspace
from scipy.stats import norm
import plotly.graph_objects as go

# %%
def plot(scale_1, scale_2):
    X = linspace(
        min((scale_1.interval(0.99)[0], scale_2.interval(0.99)[0])),
        max((scale_1.interval(0.99)[1], scale_2.interval(0.99)[1])),
        1000
    )
    return go.Figure(
        {
            'data': [
                {'y': scale_1.pdf(X), 'x': X, 'name': 'scale 1'},
                {'y': scale_2.pdf(X), 'x': X, 'name': 'scale 2', 'yaxis': 'y2'}
            ],
            'layout': {
                'yaxis2': {'side': 'right', 'overlaying': 'y'},
                'shapes': [
                    {
                        'type': 'line',
                        'yref': 'paper', 'y0': 0, 'y1': 1,
                        'xref': 'x', 'x0': true_weight, 'x1': true_weight,
                        'line': {'color': 'black', 'width': 3, 'dash': 'dash'},
                    }
                ]
            }
        }
    )

# %%
true_weight = 80

# %% [markdown]
# Imagine duas balanças:

# %% [markdown]
# * Balança 1: sempre marca +1kg acima do seu peso real. É viesada, mas consistente.

# %% [markdown]
# * Balança 2: ora marca +2kg, ora -3kg, sem padrão. É não viesada, mas tem alta variabilidade.

# %%
scale_1 = norm(true_weight + 1, 0.2)  ## eficiente, mas tendencioso
scale_2 = norm(true_weight, 2)  ## não tendencioso, mas ineficiente

# %%
plot(scale_1, scale_2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1482aecf-2a0a-448a-9790-83a4e4dc3dd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1482aecf-2a0a-448a-9790-83a4e4dc3dd3")) {                    Plotly.newPlot(                        "1482aecf-2a0a-448a-9790-83a4e4dc3dd3",                        [{"name":"scale 1","x":[74.8483413929022,74.85865502374725,74.86896865459228,74.87928228543733,74.88959591628236,74.89990954712741,74.91022317797244,74.92053680881749,74.93085043966252,74.94116407050757,74.9514777013526,74.96179133219765,74.97210496304268,74.98241859388773,74.99273222473276,75.00304585557781,75.01335948642284,75.02367311726789,75.03398674811294,75.04430037895797,75.05461400980302,75.06492764064805,75.0752412714931,75.08555490233813,75.09586853318318,75.10618216402821,75.11649579487326,75.12680942571829,75.13712305656334,75.14743668740837,75.15775031825342,75.16806394909845,75.1783775799435,75.18869121078853,75.19900484163358,75.20931847247863,75.21963210332366,75.22994573416871,75.24025936501374,75.25057299585879,75.26088662670382,75.27120025754887,75.2815138883939,75.29182751923895,75.30214115008398,75.31245478092903,75.32276841177406,75.33308204261911,75.34339567346414,75.35370930430919,75.36402293515422,75.37433656599927,75.38465019684432,75.39496382768935,75.4052774585344,75.41559108937943,75.42590472022448,75.43621835106951,75.44653198191456,75.4568456127596,75.46715924360464,75.47747287444967,75.48778650529472,75.49810013613975,75.5084137669848,75.51872739782984,75.52904102867488,75.53935465951992,75.54966829036496,75.55998192121001,75.57029555205504,75.58060918290009,75.59092281374512,75.60123644459017,75.6115500754352,75.62186370628025,75.63217733712528,75.64249096797033,75.65280459881537,75.66311822966041,75.67343186050545,75.68374549135049,75.69405912219553,75.70437275304057,75.7146863838856,75.72500001473065,75.7353136455757,75.74562727642073,75.75594090726578,75.76625453811081,75.77656816895586,75.7868817998009,75.79719543064594,75.80750906149098,75.81782269233602,75.82813632318106,75.8384499540261,75.84876358487114,75.85907721571618,75.86939084656122,75.87970447740626,75.8900181082513,75.90033173909634,75.91064536994139,75.92095900078643,75.93127263163147,75.9415862624765,75.95189989332155,75.96221352416659,75.97252715501163,75.98284078585667,75.99315441670171,76.00346804754675,76.0137816783918,76.02409530923683,76.03440894008187,76.04472257092691,76.05503620177196,76.06534983261699,76.07566346346204,76.08597709430708,76.09629072515212,76.10660435599716,76.1169179868422,76.12723161768724,76.13754524853228,76.14785887937732,76.15817251022236,76.1684861410674,76.17879977191244,76.18911340275749,76.19942703360252,76.20974066444757,76.2200542952926,76.23036792613765,76.24068155698268,76.25099518782773,76.26130881867277,76.2716224495178,76.28193608036285,76.29224971120789,76.30256334205293,76.31287697289797,76.32319060374302,76.33350423458805,76.3438178654331,76.35413149627813,76.36444512712318,76.37475875796821,76.38507238881326,76.39538601965829,76.40569965050334,76.41601328134837,76.42632691219342,76.43664054303846,76.4469541738835,76.45726780472855,76.46758143557358,76.47789506641863,76.48820869726366,76.4985223281087,76.50883595895374,76.51914958979879,76.52946322064382,76.53977685148887,76.5500904823339,76.56040411317895,76.57071774402398,76.58103137486903,76.59134500571406,76.60165863655911,76.61197226740416,76.62228589824919,76.63259952909424,76.64291315993927,76.65322679078432,76.66354042162935,76.6738540524744,76.68416768331943,76.69448131416448,76.70479494500951,76.71510857585456,76.72542220669959,76.73573583754464,76.74604946838967,76.75636309923472,76.76667673007975,76.7769903609248,76.78730399176985,76.79761762261488,76.80793125345993,7 ...

# %% [markdown]
# O ideal seria ter um estimador:
# * Sem viés (em média acerta)
# * Com baixa variabilidade (não oscila demais entre amostras)

# %%
def plot(scale_3, scale_4):
    X = linspace(
        min((scale_1.interval(0.99)[0], scale_2.interval(0.99)[0])),
        max((scale_1.interval(0.99)[1], scale_2.interval(0.99)[1])),
        1000
    )
    return go.Figure(
        {
            'data': [
                {'y': scale_3.pdf(X), 'x': X, 'name': 'scale 3'},
                {'y': scale_4.pdf(X), 'x': X, 'name': 'scale 4', 'yaxis': 'y2'}
            ],
            'layout': {
                'yaxis2': {'side': 'right', 'overlaying': 'y'},
                'shapes': [
                    {
                        'type': 'line',
                        'yref': 'paper', 'y0': 0, 'y1': 1,
                        'xref': 'x', 'x0': true_weight, 'x1': true_weight,
                        'line': {'color': 'black', 'width': 3, 'dash': 'dash'},
                    }
                ]
            }
        }
    )

# %%
scale_3 = norm(true_weight, 0.2)  ## eficiente e imparcial
scale_4 = norm(true_weight + 1, 2)  ## tendencioso e ineficiente

# %%
plot(scale_3, scale_4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2277cce1-d81f-4c70-9bac-eaa1fae17909" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("