# %% [markdown]
# # ♾️ Teorema do Limite Central

# %% [markdown]
# ##🧮 Introdução

# %% [markdown]
# O Teorema do Limite Central (TLC) afirma que, para uma população com qualquer distribuição (não precisa ser normal), a distribuição das médias amostrais tende a se aproximar de uma distribuição normal conforme o tamanho da amostra aumenta (especialmente para
# 𝑛
# ≥
# 30).

# %% [markdown]
# Ou seja: Independente da distribuição da população:
# * As médias das amostras tendem a formar uma distribuição normal. Quando coletamos várias amostras de uma população (mesmo que a distribuição da população seja completamente diferente de uma normal), a distribuição das médias amostrais vai se aproximando de uma distribuição normal à medida que o número de amostras aumenta. Quanto maior o tamanho da amostra, mais próxima de uma distribuição normal a curva das médias fica.
# * A média da distribuição amostral é aproximadamente igual à média populacional (
# 𝜇
# 𝑥
# =
# 𝜇
# ).

# %% [markdown]
# No nosso exemplo, a média da população foi de aproximadamente 16.00. A média das médias amostrais também foi próxima de 16.00, confirmando a afirmação do TLC.
#
# Distribuição das Médias Amostrais: O gráfico mostrou uma distribuição aproximadamente normal das médias amostrais, mesmo que a distribuição da população não fosse normal. Isso ocorre porque a média das amostras segue a distribuição normal, devido ao TLC.

# %% [markdown]
# ## 📐 Erro Padrão

# %% [markdown]
# Além do erro amostral, também precisamos entender o **erro padrão das médias amostrais**, que mede a variabilidade entre as médias amostrais.

# %% [markdown]
# Ou seja, o erro padrão nos diz o quanto as médias das amostras variam em torno da média populacional. Ele mede a precisão da estimativa da média que obtemos a partir de uma amost

# %% [markdown]
# O erro padrão NÃO é o desvio padrão do erro amostral diretamente, mas está relacionado ao conceito de erro amostral.

# %% [markdown]
# O erro padrão nos dá uma noção de quanto as médias amostrais flutuam em torno da média populacional se retirarmos várias amostras. Portanto, enquanto o erro amostral é uma medida pontual, o erro padrão é uma medida teórica e geral da variabilidade.

# %% [markdown]
# ![eae2121eae.png](data:image/png;base64,...)

# %% [markdown]
# O erro padrão das médias amostrais não depende de uma única amostra, mas sim de várias amostras teóricas que poderíamos tirar da população. Este cálculo é teórico e indica o desvio padrão das médias amostrais se retirássemos muitas amostras repetidamente. Ele nos dá uma ideia de quanto variam as médias das amostras em torno da média populacional.

# %%
# Calculando o erro padrão das médias amostrais
erro_padrao = pop_std / np.sqrt(n)
print(f"Erro Padrão das Médias Amostrais: {erro_padrao:.2f}")

# %% [markdown]
# OBS: Quando estamos na população completa, não se usa erro padrão, mas o desvio padrão.

# %% [markdown]
# ##🛑 Por que o TLC é Importante?

# %% [markdown]
# O TLC é fundamental porque ele nos permite:
#
# * Inferir propriedades da população mesmo que ela não tenha distribuição normal.
#
# * Aplicar testes estatísticos, como testes de hipóteses e intervalos de confiança, que assumem normalidade. A aproximação à normalidade permite aplicar métodos estatísticos paramétricos, como intervalos de confiança e testes de hipóteses, mesmo quando a população original não é normal.
#
# * Utilizar a distribuição normal para estimar médias populacionais e calcular intervalos de confiança, mesmo quando os dados originais não são normais.

# %% [markdown]
# ## ✍️ Observações

# %% [markdown]
# O Teorema do Limite Central (TLC) é um dos conceitos mais fundamentais da estatística, e ele se aplica principalmente à distribuição amostral da média, mas não exclusivamente. Vamos entender isso melhor depois.

# %% [markdown]
# Mas o fato é: Embora o TLC seja mais frequentemente usado com médias, ele também pode ser aplicado a outras estatísticas sob certas condições.
