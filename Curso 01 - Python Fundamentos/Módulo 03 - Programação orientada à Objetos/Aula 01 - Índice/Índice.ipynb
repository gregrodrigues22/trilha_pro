# %% [markdown]
# #🧠 Sobre o Módulo de Programação Orientada à Objetos (POO)

# %% [markdown]
# # 📃 Índice

# %% [markdown]
# **01. [Introdução a objetos]**
# *  Explorando valores e referências
# *  Explorando mutabilidade
# *  Variáveis locais
# *  Explorando o escopo
#
# **02. [Classes]**
# *  O que é um instância?
# *  Criando uma `classe`
# *  Usando `classes`
# *  Subclases
# *  Conceito de herança
#
# **03. [Generators]**
