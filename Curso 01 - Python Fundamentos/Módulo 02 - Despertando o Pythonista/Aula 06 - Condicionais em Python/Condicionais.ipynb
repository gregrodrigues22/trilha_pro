# %% [markdown]
# #🎯 Objetivo da Aula

# %% [markdown]
# Compreender o uso de condicionais (if, elif, else) em Python para tomada de decisões em programas.

# %% [markdown]
# **Motivação: Por que precisamos de condicionais?**

# %% [markdown]
# Condicionais permitem que seu programa responda a diferentes situações:
#
# 📌 Exemplos:
#
# 👶 Se idade < 12: mostrar “Criança”.
#
# 🌡️ Se temperatura > 37.8: mostrar “Febre”.
#
# 🗳️ Se idade ≥ 18: pode votar.

# %% [markdown]
# # 🔠 Valores Booleanos

# %%
#Os valores booleanos são um tipo de dado binário que podem assumir apenas dois valores constantes: **verdadeiro** ou **falso**

# %% [markdown]
# Os valores booleanos são um tipo de dado binário que podem assumir apenas dois valores constantes: **verdadeiro** ou **falso** (<font color=orange>**`True`**</font> ou <font color=orange> **`False`**</font>).
#
# Um exemplo prático do uso desses valores é o status do usuário (no Facebook, por exemplo), quando o usuário está offline, sua variável assume o valor falso e quando passa a estar online, sua variável assume valor verdadeiro.
#
# Esses valores são úteis para **representar o resultado de uma comparação**. Veja o exemplo abaixo:

# %%
a = 1
b = 2

a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %% [markdown]
# ***
# <font color="grey">
#  <font color="grey"><b>Diferença entre = e == :</b></font>
#
# <font color="grey">Nos exemplos acima foram usados esses dois tipos de igualdade e você já deve ter se perguntado qual a diferença entre eles.
#
#  <font color="grey">O sinal **=** representa a atribuição de um valor a uma variável.
#
#   <font color="grey">Já o sinal  **==** representa *a igualdade em si*. Costuma ser utilizado para realizar uma verificação: a variável de um lado é igual à variável do outro lado?
#
#  <font color="grey"> Além disso, podemos usar **!=** para o sinal de diferente.
#
#   <font color="grey">Agora, sabendo disso, dê uma olhadinha novamente nos exemplos acima!
#
#   ***

# %% [markdown]
# Em Python existe uma classe específica para os valores booleanos, a classe <font color="orange"><b>`bool`</b></font>.
# Lembra daquele comando que usamos para descobrir o tipo das variáveis <font color="orange"><b>`type()`</b></font>? Podemos verificar os valores booleanos também!

# %%
type (True)
# Out:
# bool

# %%
type (1==1)
# Out:
# bool

# %% [markdown]
# ***
# <font color=grey>
#  Percebeu que quando tentamos descobrir o **tipo de uma comparação**, o Python nos respondeu que a comparação é um booleano?
# Isto acontece porque sempre que existe uma comparação no código, o Python substitui está comparação por `True` ou `False`, os dois valores booleanos.
# ***

# %% [markdown]
# # 🧪 Operadores Lógicos

# %% [markdown]
# Para construirmos expressões lógicas, em linguagem de programação utilizamos os operadores lógicos. Ou seja, podemos unir dois ou mais valores booleanos em uma comparação através do uso desses operadores.
# Em Python existem 3 operadores lógicos:  <font color='orange'> **`and`** </font>, <font color='orange'> **`or`** </font> e <font color='orange'> **`not`**</font>.
#
# Exemplo: Considere dois valores booleanos A e B.

# %% [markdown]
# *  Operador <font color='orange'> **`and`** </font> ("e"): resultará em  <font color='orange'>**`True`**</font>  somente quando **ambos** A e B forem verdadeiros, caso contrário resultará em  <font color='orange'>**`False`**</font>.

# %%
a = (1 < 2)  # Neste exemplo, ambas expressões a e b são verdadeiras
b = (2 == 2)

a and b
# Out:
# True

# %%
a = (1 < 2)  # Aqui a é verdadeira, porém b não é, portanto, o resultado de a e b é falso.
b = (2 == 3)

a and b
# Out:
# False

# %% [markdown]
# *   Operador <font color='orange'> **`or`** </font> ("ou"): resultará em <font color='orange'> **`True`**</font> sempre que pelo menos **uma** das expressões A ou B forem verdadeiras, apenas se as duas forem falsas resultará em  <font color='orange'>**`False`**</font>.

# %%
a = (1 < 2) #Já neste exemplo, o "or" requere que apenas uma: a ou b seja verdadeira, por isso, mesmo b sendo falsa, atende a condição do operador.
b = (2 == 3)

a or b
# Out:
# True

# %% [markdown]
# *   Operador <font color='orange'> **`not`** </font> ("não"): é um operador de **negação**, ou seja, ele inverte o valor do argumento. <font color='orange'>**`Not True`** </font>  é   <font color='orange'>**`False`**</font> e vice-versa.

# %%
not False
# Out:
# True

# %% [markdown]
# #🧮 Estrutura básica: IF

# %% [markdown]
# Quando começamos a programar, um recurso básico que precisamos aprender são as **estruturas de condição**. Com elas podemos estipular que um código somente seja executado se uma determinada condição for satisfeita.
#
# O comando <font color='orange'> **`if`** </font> executa uma sequência de expressões **apenas se** uma determinada condição for satisfeita.

# %%
idade = 20

# %% [markdown]
# ####Exemplo 1

# %%
if idade >= 18:
  print("Maior de idade!")
  print("eba!")
# Out:
# Maior de idade!
# eba!

# %% [markdown]
# ####Exemplo 2

# %%
idade = 10
if idade >= 18:
    print("Maior de idade!")
    print("eba!")

# %% [markdown]
# Como você pode ver nesse exemplo, a condição estabelecida para o código ser executado é: a idade ser maior ou igual a 18.
#
# A estrutura <font color='orange'>**`if`**</font> no Python é seguida pela condição lógica estabelecida e por dois pontos (:). As linhas abaixo dela são as instruções que serão executadas caso a condição anterior seja antendida.

# %% [markdown]
# ***
# <font color="grey">
#  <font color="grey"><b>Identação:</b></font>
#
# <font color="grey">Aqui vai um conceito muito importante para suas estruturas de condição ficarem certinhas! O Python espera dos seus programadores um pouquinho de organização em seus códigos, assim, como você viu no exemplo acima, o comando `if` (e muitos outros) segue um padrão de espaçamento!
#
# <font color="grey">Os espaçamentos diferentes referenciam diferentes blocos. Ou seja, delimitam o começo e o fim de um comando (para aqueles que conhecem o C++, é como o famoso "abre e fecha chaves").
#
# <font color="grey">No exemplo acima, a instrução `print` está dentro do comando `if` (ela somente será executada se a condição for verdadeira), e por isso recebe o **recuo de quatro espaços**!
#
# <font color="grey">Fique ligado! Se você tentar rodar a célula e der o erro `"IndentationError: expected an indented block"`, é isso! Corrija o espaçamento e continue!

# %% [markdown]
# ####Exemplo 3

# %%
idade = 10
if idade >= 18:
    print("Maior de idade!")
print("eba!")
# Out:
# eba!

# %% [markdown]
# Perceba que nesse exemplo 3, diferente do exemplo 2, a parte **`print("eba!")`** é rodada mesmo que a idade da expressão em <font color='orange'>**`if`**</font> não seja atendida. Isso se dá pela identação (repare que são diferentes nos exemplos). Quando o **`print("eba!")`**  está identado rente à linha do <font color='orange'>**`if`**</font> temos ele idependente da condição avaliada. Já quando sua identação é mais à frente, ele é considerado um comando do <font color='orange'>**`if`**</font>, e só vai acontecer se a condição avaliada for <font color='orange'>**`True`**</font>

# %% [markdown]
# #🧮 Estrutura básica: Else

# %% [markdown]
# Nos exemplos acima, tínhamos uma reposta somente quando a condição estipulada era atendida. Quando não era, nada era impresso. Então, se a idade fosse menor que 18 o programa simplesmente não te respondia. Mas bem que ele podia, né?
#
# Para isso, é preciso que você estipule o que ele deve responder com o comando <font color='orange'>**`else`**</font>.

# %%
idade = 10
if idade >= 18:
  print("Maior de idade!")
else:
  print ("Menor de idade!")
# Out:
# Menor de idade!

# %% [markdown]
# O comando <font color='orange'>**`else`**</font> serve para todas as outras possibilidades que não atendem a condição estabelecida no <font color='orange'>**`if`**</font>.
# Portanto, todas as idades menores que `18` serão executadas pelo <font color='orange'>**`else`**</font>.

# %% [markdown]
# #🧮 Estrutura básica: Elif

# %% [markdown]
# O exemplo que foi usado tinha apenas 2 opções:
#
#
# *   Maior de idade
# *   Menor de idade
#
# Acontece que nem sempre é assim. Podemos usar um novo exemplo, como classificar pela idade em:
#
# *   Criança
# *   Adolescente
# *   Adulto
#
# Perceba que dessa forma, existe mais de 1 possibilidade, então só o <font color='orange'>**`if`**</font> e o <font color='orange'>**`else`**</font> não seriam suficientes. Para isso, existe o <font color='orange'>**`elif`**</font> (precisamos admitir que eles mandaram bem no nome).
#
# Essa ferramenta nos permite impor múltiplas condições.

# %%
idade = 10
if idade < 12:
  print("Criança")
elif idade < 18:
  print ("Adolescente")
else:
  print ("Adulto")
# Out:
# Criança

# %% [markdown]
# ***
# <font color="grey">
# <b>Perceba:</b>
#
#   O <font color='orange'>**`else`**</font> só acontece quando **nenhuma** das outras condições é atendida.
#
# ***

# %% [markdown]
# É importante ter em mente que as condições impostas nos <font color='orange'>**`if`**</font>s, nos <font color='orange'>**`elif`**</font>s e no<font color='orange'>** `else` **</font> são excludentes entre si! Ou seja, se o programa entender que o primeiro <font color='orange'>**`if`**</font> é verdadeiro, vai devolver o que estiver identado logo depois do <font color='orange'>**`if`**</font> e ignorar as outras opções.

# %% [markdown]
# ####Exemplo 1

# %%
x = 30
if (x % 2) == 0:
    print(f'{x} é par')
elif x > 20:
    print(f'{x} é maior que 20')
# Out:
# 30 é par

# %% [markdown]
# Observe que, nesse caso, as condições de <font color='orange'> **`if`**</font> e <font color='orange'>**`elif`**</font>  que estipulamos, na verdade,  não são excludentes. `30` é, de fato, tanto par quanto maior que `20`, mas o programa não entende isso sozinho. É necessário que você mostre isso usando<font color='orange'> **`if`</font> para ambas as condições**, assim ele vai entender que são duas condições independentes.

# %% [markdown]
# ####Exemplo 2

# %%
x = 30
if (x % 2) == 0:
    print(f'{x} é par')
if x > 20:
    print(f'{x} é maior que 20')
# Out:
# 30 é par
# 30 é maior que 20

# %% [markdown]
# Outro diferencial do Python em questão de simplicidade é que você pode montar **todo esse esquema de condições em uma única sentença**. Fica quase uma frase! Para quem nunca programou com outras linguagens antes não aparece o tamanho da evolução que isso é, mas confia! O negócio é simples mesmo.

# %%
nota = 4.5
resultado = 'Aprovado' if nota > 5.75 else 'Não aprovado'
print(resultado)
# Out:
# Não aprovado

# %%
nota = 4.5
if nota > 5.75:
    resultado = 'Aprovado'
else:
    resultado = 'Não aprovado'
print(resultado)
# Out:
# Não aprovado

# %% [markdown]
# ***
# <font color="grey">
# <b>Atenção:</b>
#
#   <font color="grey">É importante lembrar que os dados booleanos <font color='orange'>**`True`**</font> e <font color='orange'>**`False`**</font> são, necessariamente, escritos com a **primeira letra maiúscula** para que o Python os reconheça.
#
#  <font color="grey">Esse padrão chama **CamelCase**, quando um comando com uma ou mais palavras concatenadas demandam as primeiras letras maiúsculas. Você vai encontrar isso em várias outras linguagens.
#
# ***

# %% [markdown]
# # 💪 Exercício

# %% [markdown]
# * **Questão 1**

# %% [markdown]
# Dado a sequência de números: 6, 3, 9, 4, 2, 2, 7. Escreva um programa que calcule a soma dos números pares e quantos números da sequência são pares.
# Dica: utilize o operador "%", que retorna o resto da divisão (usamos nessa apostila).

# %% [markdown]
# * **Questão 2**

# %% [markdown]
# Escreva um programa que coloque os números em ordem decrescente. Sendo eles: a=5, b=8, c=3.
