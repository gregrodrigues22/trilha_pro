# %% [markdown]
# #🎯 Strings

# %% [markdown]
# As <font color = "orange"><b>`strings`</font></b> são uma classe de objetos compostas por uma sequência de caracteres. Para que o interpretador entenda que você está usando uma <font color = "orange"><b>`string`</font></b>, é necessário que ela seja representada entre aspas (simples ou duplas, você escolhe!)

# %%
minha_string = "Um copo de água"
print (minha_string)
# Out:
# Um copo de água

# %%
outra_string = 'Dois copos de água'
print (outra_string)
# Out:
# Dois copos de água

# %%
string_errada = 'Muitos copos de água"
print (string_errada)

# %%
string_teste = 'Um copo d'água'
print (string_teste)

# %% [markdown]
# Se você precisa usar um apóstrofe dentro da <font color = "orange"><b>`string`</font></b>, pode fazer das seguintes maneiras:

# %%
string_outro_teste = "copo d'água"
print (string_outro_teste)
# Out:
# copo d'água

# %%
string_outro_teste = "copo d'água"
print (string_outro_teste)
# Out:
# copo d'água

# %%
string_mais_um_teste = 'copo d\'água'
print (string_mais_um_teste)
# Out:
# copo d'água

# %% [markdown]
# Ou até usar aspas:

# %%
msg = 'vou usar o celular só para "usar a calculadora"'
print (msg)
# Out:
# vou usar o celular só para "usar a calculadora"

# %% [markdown]
# # 🧠 Operações com Strings

# %% [markdown]
# Além disso, você pode realizar operações com <font color = "orange"><b>`strings`</font></b>:

# %%
"piu" * 3
# Out:
# 'piupiupiu'

# %%
'piu' + "piu"
# Out:
# 'piupiu'

# %% [markdown]
# # 📌 O "Enter"

# %%
string_com_enter = "oi,
tudo bem?"
print (string_com_enter)

# %% [markdown]
# Perceba que Python não reconhece o "enter" no meio da <font color = "orange"><b>`string`</font></b>.
#
# Para fazê-lo entender, é necessário usar <font color = "orange"><b>`\n`</font> </b> ou então usar aspas triplas (<font color = "orange"><b>`'''`</font></b>).
#
# Perceba também que é possível escrever várias <font color = "orange"><b>`strings`</font></b> numa mesma variável entre parênteses.
#
# **Por exemplo:**

# %%
música = ('O cravo brigou com a rosa\n'  #não esqueça de finalizar com \n
          'Debaixo de uma sacada\n'
          'O cravo saiu ferido\n'
          'E a rosa despedaçada')
print (música)
# Out:
# O cravo brigou com a rosa
# Debaixo de uma sacada
# O cravo saiu ferido
# E a rosa despedaçada

# %%
música = '''O cravo brigou com a rosa
          Debaixo de uma sacada
          O cravo saiu ferido
          E a rosa despedaçada'''
print (música)
# Out:
# O cravo brigou com a rosa
#           Debaixo de uma sacada
#           O cravo saiu ferido
#           E a rosa despedaçada

# %% [markdown]
# # 🧭 Transformações de String

# %% [markdown]
# Ainda, se quiser escrever algo em letra maiúscula, pode usar a função <font color = "orange">**`upper()`**</font>:

# %%
"piu".upper()
# Out:
# 'PIU'

# %% [markdown]
# Ou, também, passar para letras minúsculas, usando a função <font color = "orange">**`lower()`**</font>:

# %%
"PIU".lower()
# Out:
# 'piu'

# %% [markdown]
# Sabemos que é mais fácil usar o "Caps Lock" para o exemplo acima, mas tome um exemplo mais longo.

# %%
exemplo_longo = '1 elefante incomoda muita gente. 2 elefantes incomodam, incomodam muito mais. 3 elefantes incomodam muita gente, 4 elefantes incomodam, incomodam, incomodam, incomodam muito mais.'

# %%
exemplo_longo.upper()
# Out:
# '1 ELEFANTE INCOMODA MUITA GENTE. 2 ELEFANTES INCOMODAM, INCOMODAM MUITO MAIS. 3 ELEFANTES INCOMODAM MUITA GENTE, 4 ELEFANTES INCOMODAM, INCOMODAM, INCOMODAM, INCOMODAM MUITO MAIS.'

# %% [markdown]
# Se você tivesse que mudar toda essa <font color = "orange"><b>`string`</font></b> para caixa alta daria muito mais trabalho reescrevê-la com caps lock do que usar a função upper!
#
# E ainda, podemos corrigir um texto que sem querer foi escrito todo em letras maiúsculas com a função <font color = "orange">**`capitalize()`**</font>.

# %%
msg = 'OI, TUDO BEM?'
msg.capitalize()
# Out:
# 'Oi, tudo bem?'

# %% [markdown]
# Além de tudo isso, você ainda pode descobrir quantos caracteres tem uma <font color = "orange"><b>`string`</font></b> (ou seja, seu comprimento):

# %%
len("Piu")
# Out:
# 3

# %% [markdown]
# Ou mesmo, achar uma letra específica. Por exemplo a primeira letra da <font color = "orange"><b>`string`</font></b>.

# %%
nome = 'Maria Eduarda'
primeira_letra = nome[0] #perceba que a posição inicial é a 0

# %%
primeira_letra
# Out:
# 'M'

# %%
quarta_letra = nome[3]
quarta_letra
# Out:
# 'i'

# %%
última_letra = nome[len(nome)-1]  #lembre-se que a contagem da string começa em 0,
última_letra                      #então a última letra é o número de letras da string - 1
# Out:
# 'a'

# %% [markdown]
# Se quisermos uma parte da <font color = "orange"><b>`string`</font></b>:

# %% [markdown]
# **string[início:fim:passo]**

# %% [markdown]
# * início: onde começa (inclusivo)
# * fim: onde para (exclusivo)
# * passo: de quanto em quanto (pode ser negativo)

# %%
#Vai do início da string até o índice 5 (exclusivo). Ou seja, pega os caracteres de índice 0 a 4:

nome[:5]
# Out:
# 'Maria'

# %%
#Esse é um truque para inverter a string.
#::-1 significa: percorra do fim para o começo, pulando de -1 em -1.

nome[::-1]
# Out:
# 'adraudE airaM'

# %%
#Vai do índice 1 até o final da string.
#Começa em a (índice 1), depois segue normalmente.

nome[1:]
# Out:
# 'aria Eduarda'

# %%
#Essa é uma fatia invertida.
#Começa em índice 5 (' ' espaço) e vai até o índice 1 (exclusivo), pulando de -1 em -1.
#Ou seja, lê de trás pra frente os caracteres de índice 5 a 2:

nome[5:1:-1]
# Out:
# ' air'

# %% [markdown]
# # ✅ Imutabilidade

# %% [markdown]
# É importante lembrar que os objetos do tipo <font color = "orange"><b>`string`</font></b> são imutáveis, ou seja, não podemos alterá-los! Talvez você me conteste dizendo que já mudamos uma <font color = "orange"><b>`string`</font></b> antes (quando colocamos elas em letras maiúsculas, por exemplo).
#
# Na verdade nós não as alteramos, apenas ordenamos ao programa que as imprimissem de outra maneira. O que acontece é que elas terão **endereços diferentes**, ou seja, o Python cria um novo objeto (a <font color = "orange"><b>`string`</font></b> impressa do jeito que você mandou) e os diferencia ocupando dois espaços diferentes na memória.

# %%
uma_string = 'oi, tudo bem?'

# %%
id(uma_string)  #Esse é o número de identificação desse objeto para o programa.
# Out:
# 133599543093744

# %%
uma_string.upper()
# Out:
# 'OI, TUDO BEM?'

# %%
id(uma_string.upper())  #Percebeu que não é o mesmo número? Portanto, não são o mesmo objeto!
# Out:
# 133599542961008

# %%
uma_string == uma_string.upper()
# Out:
# False

# %% [markdown]
# Como falamos agora, não podemos mudar uma <font color = "orange"><b>`string`</font></b>, portanto, olha o que acontece se quisermos mudar um carácter dela:

# %%
uma_string[0]
# Out:
# 'o'

# %%
uma_string[0] = 'P'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-36-2551642622.py in <cell line: 0>()
# ----> 1 uma_string[0] = 'P'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # 📦 Função replace

# %% [markdown]
# Essa função substitui uma parte do texto por uma outra <font color = "orange"><b>`string`</font></b>!

# %%
uma_string
# Out:
# 'oi, tudo bem?'

# %%
uma_string.replace('oi', 'Olá')
# Out:
# 'Olá, tudo bem?'

# %%
uma_string
# Out:
# 'oi, tudo bem?'

# %% [markdown]
# **IMPORTANTE!**
#
# A função <font color = "orange"><b>`replace()`</font></b> devolve uma **nova string**, já que são imutáveis. Se você buscar os lugares de cada uma na memória, serão diferentes de novo! (:

# %% [markdown]
# # 💪 Exercício

# %% [markdown]
# * **Questão 1**

# %% [markdown]
# Dado uma `string`, escreva um programa que conte quantas vogais e quantos espaços em branco existem nela.

# %% [markdown]
# * **Questão 2**

# %% [markdown]
# Escreva um código que verifique se uma `string` é um palíndromo, ou seja, uma palavra que se escreve do mesmo jeito de trás para frente. Exemplo de palíndromo: 'radar'.
