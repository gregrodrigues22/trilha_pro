# %% [markdown]
# # 📌 Análise exploratória de Dados (EDA)

# %% [markdown]
# ## 1️⃣ O que é uma EDA?

# %% [markdown]
# > ‘Exploratory data analysis’ is an attitude, a state of flexibility, a willingness to look for those things that we believe are not there, as well as those we believe to be there.” Jonh Tukey

# %% [markdown]
# ![1245.png](data:image/png;base64,...)

# %% [markdown]
# [Clique aqui para artigo no Blog da P2P](https://www.linkedin.com/pulse/an%C3%A1lise-explorat%C3%B3ria-de-dados-sa%C3%BAde-com-python-10-passos-rodrigues)

# %% [markdown]
# ## 2️⃣ Descobrindo pérolas

# %% [markdown]
# Slide da aula de Data Story telling

# %% [markdown]
# ![123456789.png](data:image/png;base64,...)

# %% [markdown]
# ## 3️⃣ Tudo começa com perguntas

# %% [markdown]
# Slide da aula de Interpretação

# %% [markdown]
# ![1234567890.png](data:image/png;base64,...)

# %% [markdown]
# ![1111.png](data:image/png;base64,...)
