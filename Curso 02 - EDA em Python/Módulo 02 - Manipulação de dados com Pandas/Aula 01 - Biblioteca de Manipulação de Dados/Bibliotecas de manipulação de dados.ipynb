# %% [markdown]
# # 📌 Bibliotecas ou Pacotes

# %% [markdown]
# ## 1️⃣ O que são bibliotecas?

# %% [markdown]
# Bibliotecas são coleções de módulos e funções que facilitam o desenvolvimento sem precisar escrever código do zero.

# %% [markdown]
# ##2️⃣ Exemplos de Bibliotecas

# %% [markdown]
# | 📚 Biblioteca  | 📌 Função |
# |--------------|----------|
# | **Pandas** | Manipulação de dados tabulares (DataFrames), como excel do python|
# | **NumPy** | Operações matemáticas e manipulação de arrays |
# | **Matplotlib** | Criação de gráficos básicos |
# | **Seaborn** | Visualização estatística mais avançada |
# | **Scipy** | Computação científica |
# | **Plotly** | Gráficos interativos |

# %% [markdown]
# ## 3️⃣ Como instalar bibliotecas no Colab?

# %% [markdown]
# Muitas bibliotecas já vêm instaladas, mas podemos adicionar novas com o comando:

# %% [markdown]
# **pip install nome_da_biblioteca**

# %%
#Teste rodando essa cédula, que instala bibliotecas com alias (apelidos, para facilitar a digitação)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
